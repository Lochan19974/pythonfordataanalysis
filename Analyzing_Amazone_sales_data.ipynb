# %%
import pandas as pd
import os

# %%
os.listdir(r'D:\data_analytics_dataset\amazone_sales_project\Amazon Sales project')
# Out:
# ['sales_data.xlsx']

# %%
sd=pd.read_excel(r'D:\data_analytics_dataset\amazone_sales_project\Amazon Sales project/sales_data.xlsx')

# %%
sd.head(5)
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# 0   Merchant      Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1   Merchant      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2     Amazon      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
# 3   Merchant      Amazon.in           Standard    J0341       J0341-DR-L
# 4     Amazon      Amazon.in          Expedited  JNE3671  JNE3671-TU-XXXL
#
#   Category  ... Qty currency  Amount    ship-city   ship-state  \
# ...

# %%
sd.size
# Out:
# 2966425

# %%
sd.describe()
# Out:
#                index            Qty         Amount  ship-postal-code  \
# count  128975.000000  128975.000000  121180.000000     128935.000000
# mean    64487.000000       0.904431     648.561465     463963.108256
# std     37232.019822       0.313354     281.211687     191475.865632
# min         0.000000       0.000000       0.000000     110001.000000
# 25%     32243.500000       1.000000     449.000000     382421.000000
# 50%     64487.000000       1.000000     605.000000     500033.000000
# 75%     96730.500000       1.000000     788.000000     600024.000000
# max    128974.000000      15.000000    5584.000000     989898.000000
#
#                  B2B
# count  128968.000000
# mean        0.006754
# std         0.081903
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000

# %%
sd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128975 entries, 0 to 128974
# Data columns (total 23 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128975 non-null  int64
#  1   Order ID            128975 non-null  object
#  2   Date                128975 non-null  object
#  3   Status              128975 non-null  object
#  4   Fulfilment          128975 non-null  object
#  5   Sales Channel       128975 non-null  object
#  6   ship-service-level  128975 non-null  object
#  7   Style               128975 non-null  object
#  8   SKU                 128975 non-null  object
#  9   Category            128975 non-null  object
#  10  Size                128975 non-null  object
#  11  ASIN                128975 non-null  object
#  12  Courier Status      122103 non-null  object
#  13  Qty                 128975 non-null  int64
#  14  currency            121180 non-null  object
# ...

# %%
sd.isnull().sum()
# Out:
# index                     0
# Order ID                  0
# Date                      0
# Status                    0
# Fulfilment                0
# Sales Channel             0
# ship-service-level        0
# Style                     0
# SKU                       0
# Category                  0
# Size                      0
# ASIN                      0
# Courier Status         6872
# Qty                       0
# currency               7795
# Amount                 7795
# ship-city                33
# ship-state               40
# ship-postal-code         40
# ship-country             40
# promotion-ids         49160
# B2B                       7
# fulfilled-by          89699
# dtype: int64

# %%
sd.columns
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel ',
#        'ship-service-level', 'Style', 'SKU', 'Category', 'Size', 'ASIN',
#        'Courier Status', 'Qty', 'currency', 'Amount', 'ship-city',
#        'ship-state', 'ship-postal-code', 'ship-country', 'promotion-ids',
#        'B2B', 'fulfilled-by'],
#       dtype='object')

# %%
sd.dtypes
# Out:
# index                   int64
# Order ID               object
# Date                   object
# Status                 object
# Fulfilment             object
# Sales Channel          object
# ship-service-level     object
# Style                  object
# SKU                    object
# Category               object
# Size                   object
# ASIN                   object
# Courier Status         object
# Qty                     int64
# currency               object
# Amount                float64
# ship-city              object
# ship-state             object
# ship-postal-code      float64
# ship-country           object
# promotion-ids          object
# B2B                   float64
# fulfilled-by           object
# dtype: object

# %%
#cleaning the data

# %%
#check for missing data

# %%
sd.isnull().sum()
# Out:
# index                     0
# Order ID                  0
# Date                      0
# Status                    0
# Fulfilment                0
# Sales Channel             0
# ship-service-level        0
# Style                     0
# SKU                       0
# Category                  0
# Size                      0
# ASIN                      0
# Courier Status         6872
# Qty                       0
# currency               7795
# Amount                 7795
# ship-city                33
# ship-state               40
# ship-postal-code         40
# ship-country             40
# promotion-ids         49160
# B2B                       7
# fulfilled-by          89699
# dtype: int64

# %%
sd_dp=sd.dropna()

# %%
sd.shape
# Out:
# (128975, 23)

# %%
sd_dp.shape #huge amount of data is loss. so it is not good for analysis.
# Out:
# (32337, 23)

# %%
#drop rows with missing amounts based on the amount column

# %%
sd_clean= sd.dropna(subset=['Amount'])

# %%
sd_clean.shape
# Out:
# (121180, 23)

# %%
'''
question to be answered:
- How many sales have they made with amounts more than 1000
- How many sales have they made that belong to the category 'top' and have a quantity of three.
- The Total Sales by category
- Average amount by category and status
- Total sales by fulfilment and shipment type
'''
# Out:
# "\nquestion to be answered:\n- how many sales have they made with amounts more than 1000\n-How many sales have they made that belong to the category 'top' and have a quantity of three.\n-The Total Sales by category\n-average amount by category and status\n-Total sales by fulfilment and shipment type\n"

# %%
#aggregating data

# %%
#Total sles by category

# %%
sd.columns
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel ',
#        'ship-service-level', 'Style', 'SKU', 'Category', 'Size', 'ASIN',
#        'Courier Status', 'Qty', 'currency', 'Amount', 'ship-city',
#        'ship-state', 'ship-postal-code', 'ship-country', 'promotion-ids',
#        'B2B', 'fulfilled-by'],
#       dtype='object')

# %%
category_totals = sd.groupby('Category')['Amount'].sum()

# %%
# Group the data by the 'Category' column and calculate the sum of 'Amount' for each category
category_totals = sd.groupby('Category')['Amount'].sum()

# %%
category_totals = sd.groupby('Category', as_index=False)['Amount'].sum()

# %%
# Group the data by 'Category', calculate the sum of 'Amount' for each category
# 'as_index=False' keeps 'Category' as a column rather than an index in the result
category_totals = sd.groupby('Category', as_index=False)['Amount'].sum()

# %%
category_totals
# Out:
#   Category       Amount
# 0   Blouse  21757954.88
# 1   Bottom    150667.98
# 2    Dress  12131224.11
# 3    Scarf       915.00
# 4      Set  39204124.03
# 5      Top   5347792.30

# %%
category_totals = category_totals.sort_values('Amount', ascending=False)

# %%
# Sort the category_totals DataFrame by the 'Amount' column in descending order (largest values first)
category_totals = category_totals.sort_values('Amount', ascending=False)

# %%
category_totals
# Out:
#   Category       Amount
# 4      Set  39204124.03
# 0   Blouse  21757954.88
# 2    Dress  12131224.11
# 5      Top   5347792.30
# 1   Bottom    150667.98
# 3    Scarf       915.00

# %%
fullfilment_average = sd.groupby(['Category','Fulfilment'])['Amount'].mean()

# %%
# Calculate the average amount spent per category and fulfillment type
# Groups the data by both 'Category' and 'Fulfilment' columns, then computes the mean of 'Amount' for each group
fullfilment_average = sd.groupby(['Category','Fulfilment'])['Amount'].mean()

# %%
fullfilment_average = sd.groupby(['Category','Fulfilment'], as_index=False)['Amount'].mean()

# %%
# Calculate the average amount spent per category and fulfillment type
# Groups the data by both 'Category' and 'Fulfilment' columns
# as_index=False keeps Category and Fulfilment as columns rather than index
# Then computes the mean of the 'Amount' column for each group
fullfilment_average = sd.groupby(['Category','Fulfilment'], as_index=False)['Amount'].mean()

# %%
fullfilment_average = fullfilment_average.sort_values('Amount', ascending=False)

# %%
fullfilment_average
# Out:
#    Category Fulfilment      Amount
# 7       Set     Amazon  838.042180
# 8       Set   Merchant  822.466512
# 4     Dress     Amazon  776.077009
# 5     Dress   Merchant  740.499730
# 9       Top     Amazon  536.449448
# 10      Top   Merchant  493.678577
# 0    Blouse     Amazon  459.493705
# 1    Blouse   Merchant  451.327641
# 2    Bottom     Amazon  365.080508
# 3    Bottom   Merchant  350.592283
# 6     Scarf     Amazon  305.000000

# %%
status_average = sd.groupby(['Category','Status'], as_index=False)['Amount'].mean()

# %%
# Group the data by 'Category' and 'Status', then calculate the mean 'Amount' for each group
# The as_index=False parameter keeps 'Category' and 'Status' as columns rather than as index
status_average = sd.groupby(['Category','Status'], as_index=False)['Amount'].mean()

# %%
status_average = status_average.sort_values('Amount', ascending=False)

# %%
status_average
# Out:
#    Category                         Status       Amount
# 24    Dress              Shipped - Damaged  1136.000000
# 39      Set     Shipped - Out for Delivery   908.105263
# 29    Dress    Shipped - Rejected by Buyer   899.000000
# 43      Set  Shipped - Returning to Seller   875.835616
# 40      Set            Shipped - Picked Up   846.322660
# 34      Set                        Pending   837.629482
# 36      Set                        Shipped   836.530584
# 37      Set   Shipped - Delivered to Buyer   827.042759
# 33      Set                      Cancelled   826.970953
# 42      Set   Shipped - Returned to Seller   824.475817
# 35      Set  Pending - Waiting for Pick Up   791.120370
# 31    Dress  Shipped - Returning to Seller   782.642857
# 23    Dress                        Shipped   774.604673
# 22    Dress  Pending - Waiting for Pick Up   767.531646
# 27    Dress     Shipped - Out for Delivery   765.000000
# 20    Dress                      Cancelled   752.765319
# ...

# %%
#calculate total sales by shipment and fulfilment

# %%
total_sales_shipedandfulfil = sd.groupby(['Courier Status','Fulfilment'], as_index=False)['Amount'].sum()

# %%
total_sales_shipedandfulfil = total_sales_shipedandfulfil.sort_values('Amount', ascending=False)

# %%
total_sales_shipedandfulfil
# Out:
#   Courier Status Fulfilment      Amount
# 1        Shipped     Amazon  50331934.0
# 2        Shipped   Merchant  20726730.0
# 3      Unshipped     Amazon   3990217.0
# 4      Unshipped   Merchant    353625.0
# 0      Cancelled     Amazon         0.0

# %%
total_sales_shipedandfulfil.rename(columns={'Courier Status': 'Shipment'}, inplace =True)

# %%
# Rename the 'Courier Status' column to 'Shipment' in the total_sales_shipedandfulfil DataFrame
# The inplace=True parameter means the DataFrame is modified directly without needing to assign it back
total_sales_shipedandfulfil.rename(columns={'Courier Status': 'Shipment'}, inplace=True)

# %%
total_sales_shipedandfulfil
# Out:
#     Shipment Fulfilment      Amount
# 1    Shipped     Amazon  50331934.0
# 2    Shipped   Merchant  20726730.0
# 3  Unshipped     Amazon   3990217.0
# 4  Unshipped   Merchant    353625.0
# 0  Cancelled     Amazon         0.0

# %%
#exporting the data

# %%
status_average.to_excel('average_sales_by_category_and_status.xlsx', index=False)
